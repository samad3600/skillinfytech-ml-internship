# %%
import pandas as pd
import numpy as np
import string
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
fake = pd.read_csv("Fake.csv")
true = pd.read_csv("True.csv")

fake["label"] = 0
true["label"] = 1

data = pd.concat([fake, true])
data = data.sample(frac=1).reset_index(drop=True)

data.head()
# Out:
#                                                title  \
# 0  TEXAS CIVIL RIGHTS LAWYER and Dartmouth Grad S...
# 1  IF JOE BIDEN DECIDES TO RUN FOR PRESIDENT, THI...
# 2  Obama says $38 billion Israel aid package to h...
# 3   Texas Trump Fan Threatened To ‘Whip’ Black Ma...
# 4  House Speaker Ryan backs swift action on Iran,...
#
#                                                 text       subject  \
# 0  Texas Civil Rights lawyer Rob Ranco is a partn...      politics
# 1  Here s Biden chuckling and grinning while deba...      politics
# 2  WASHINGTON (Reuters) - President Barack Obama ...  politicsNews
# 3  It s no secret that Donald Trump s rabid, uned...          News
# 4  WASHINGTON (Reuters) - U.S. House of Represent...  politicsNews
#
#                   date  label
# 0          Sep 9, 2017      0
# 1         Aug 23, 2015      0
# 2  September 14, 2016       1
# 3   September 13, 2017      0
# 4       June 22, 2017       1

# %%
def clean_text(text):
    text = text.lower()
    text = text.translate(str.maketrans('', '', string.punctuation))
    return text

data["text"] = data["text"].apply(clean_text)

# %%
X = data["text"]
y = data["label"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

vectorizer = TfidfVectorizer(stop_words='english', max_df=0.7)

X_train = vectorizer.fit_transform(X_train)
X_test = vectorizer.transform(X_test)

model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, pred))
# Out:
# Accuracy: 0.983630289532294

# %%
def predict_news(news):
    news = clean_text(news)
    vect = vectorizer.transform([news])
    prediction = model.predict(vect)
    return "Real News" if prediction[0] == 1 else "Fake News"

# %%
predict_news("Breaking: Government announces new policy on education reform")
# Out:
# 'Fake News'

# %%
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (1.30.0)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from streamlit) (4.2.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: importlib-metadata<8,>=1.4 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from streamlit) (7.0.1)
# Requirement already satisfied: numpy<2,>=1.19.3 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<24,>=16.8 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from streamlit) (23.2)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from streamlit) (2.1.4)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from streamlit) (10.2.0)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=6.0 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from streamlit) (14.0.2)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from streamlit) (13.3.5)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: tzlocal<6,>=1.1 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from streamlit) (2.1)
# Requirement already satisfied: validators<1,>=0.2 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from streamlit) (0.18.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from streamlit) (3.1.37)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from streamlit) (6.3.3)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from streamlit) (4.0.1)
# Requirement already satisfied: jinja2 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.19.2)
# Requirement already satisfied: toolz in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: colorama in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: zipp>=0.5 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from importlib-metadata<8,>=1.4->streamlit) (3.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from python-dateutil<3,>=2.7.3->streamlit) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2024.8.30)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from validators<1,>=0.2->streamlit) (5.1.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\abdul samad yaqoob\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
